# %%
import matplotlib.pyplot as plt

# %%
file1="/Users/gaogao/Desktop/DD2424/Assignment3/3_noraml/validation_accuracy.txt"
file2="/Users/gaogao/Desktop/DD2424/Assignment3/3_noraml/train_accuracy.txt"

lines  = open(file1,'r') 
for line in lines:
    y1 = eval(line)#这里用eval将字符串转换为代码来执行

lines  = open(file2,'r') 
for line in lines:
    y2= eval(line)#这里用eval将字符串转换为代码来执行

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='train') 
ax.plot(x, y2, label='validation') 
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('Accuracy')
ax.legend()

plt.show()

# %%
file1="/Users/gaogao/Desktop/DD2424/Assignment3/3_noraml/validation_cost.txt"
file2="/Users/gaogao/Desktop/DD2424/Assignment3/3_noraml/train_cost.txt"
va=open(file1,'r').read()
tr=open(file2,'r').read()
import re
pattern = re.compile(r'(?<=numpy=)\d+\.?\d*')
a=pattern.findall(va)
b=pattern.findall(tr)
y1,y2=[],[]
for i in a:
    y1.append(eval(i))
for i in b:
    y2.append(eval(i))

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('cost')
ax.set_title('cost')
ax.legend()

plt.show()

# %%
file1="/Users/gaogao/Desktop/DD2424/Assignment3/3_bn_lmd/lmd_bn_train_accuracy.txt"
file2="/Users/gaogao/Desktop/DD2424/Assignment3/3_bn_lmd/lmd_bn_validation_accuracy.txt"

lines  = open(file1,'r') 
for line in lines:
    y1 = eval(line)#这里用eval将字符串转换为代码来执行

lines  = open(file2,'r') 
for line in lines:
    y2= eval(line)#这里用eval将字符串转换为代码来执行
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='train') 
ax.plot(x, y2, label='validation') 
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('Accuracy')
ax.legend()

plt.show()

# %%
file1="/Users/gaogao/Desktop/DD2424/Assignment3/3_bn_lmd/lmd_bn_validation_cost.txt"
file2="/Users/gaogao/Desktop/DD2424/Assignment3/3_bn_lmd/lmd_bn_train_cost.txt"
va=open(file1,'r').read()
tr=open(file2,'r').read()
import re
pattern = re.compile(r'(?<=numpy=)\d+\.?\d*')
a=pattern.findall(va)
b=pattern.findall(tr)
y1,y2=[],[]
for i in a:
    y1.append(eval(i))
for i in b:
    y2.append(eval(i))
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('cost')
ax.set_title('cost')
ax.legend()

plt.show()

# %%
file1="/Users/gaogao/Desktop/DD2424/Assignment3/9_normal/9_validation_accuracy.txt"
file2="/Users/gaogao/Desktop/DD2424/Assignment3/9_normal/9_train_accuracy.txt"

lines  = open(file1,'r') 
for line in lines:
    y1 = eval(line)#这里用eval将字符串转换为代码来执行

lines  = open(file2,'r') 
for line in lines:
    y2= eval(line)#这里用eval将字符串转换为代码来执行
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('Accuracy')
ax.legend()

plt.show()

# %%
file1="/Users/gaogao/Desktop/DD2424/Assignment3/9_normal/9_validation_cost.txt"
file2="/Users/gaogao/Desktop/DD2424/Assignment3/9_normal/9_train_cost.txt"
va=open(file1,'r').read()
tr=open(file2,'r').read()
import re
pattern = re.compile(r'(?<=numpy=)\d+\.?\d*')
a=pattern.findall(va)
b=pattern.findall(tr)
y1,y2=[],[]
for i in a:
    y1.append(eval(i))
for i in b:
    y2.append(eval(i))
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('cost')
ax.set_title('cost')
ax.legend()

plt.show()

# %%
file1="/Users/gaogao/Desktop/DD2424/Assignment3/9_bn/9bn_validation_accuracy.txt"
file2="/Users/gaogao/Desktop/DD2424/Assignment3/9_bn/9bn_train_accuracy.txt"

lines  = open(file1,'r') 
for line in lines:
    y1 = eval(line)#这里用eval将字符串转换为代码来执行

lines  = open(file2,'r') 
for line in lines:
    y2= eval(line)#这里用eval将字符串转换为代码来执行
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,89)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('Accuracy')
ax.legend()

plt.show()

# %%
file1="/Users/gaogao/Desktop/DD2424/Assignment3/9_bn/9bn_validation_cost.txt"
file2="/Users/gaogao/Desktop/DD2424/Assignment3/9_bn/9bn_train_cost.txt"
va=open(file1,'r').read()
tr=open(file2,'r').read()
import re
pattern = re.compile(r'(?<=numpy=)\d+\.?\d*')
a=pattern.findall(va)
b=pattern.findall(tr)
y1,y2=[],[]
for i in a:
    y1.append(eval(i))
for i in b:
    y2.append(eval(i))
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,89)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('cost')
ax.set_title('cost')
ax.legend()

plt.show()

# %%
file1="/Users/gaogao/Desktop/DD2424/Assignment3/3_bn_lmd/lmd_bn_validation_accuracy.txt"
file2="/Users/gaogao/Desktop/DD2424/Assignment3/3_bn_lmd/lmd_bn_train_accuracy.txt"

lines  = open(file1,'r') 
for line in lines:
    y1 = eval(line)#这里用eval将字符串转换为代码来执行

lines  = open(file2,'r') 
for line in lines:
    y2= eval(line)#这里用eval将字符串转换为代码来执行
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('Accuracy')
ax.legend()

plt.show()

# %%
file1="/Users/gaogao/Desktop/DD2424/Assignment3/3_bn_lmd/lmd_bn_validation_cost.txt"
file2="/Users/gaogao/Desktop/DD2424/Assignment3/3_bn_lmd/lmd_bn_train_cost.txt"
va=open(file1,'r').read()
tr=open(file2,'r').read()
import re
pattern = re.compile(r'(?<=numpy=)\d+\.?\d*')
a=pattern.findall(va)
b=pattern.findall(tr)
y1,y2=[],[]
for i in a:
    y1.append(eval(i))
for i in b:
    y2.append(eval(i))
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('cost')
ax.set_title('cost')
ax.legend()

plt.show()

# %%
file2="/Users/gaogao/Desktop/DD2424/Assignment3/1e-1_train_accuracy.txt"
file1="/Users/gaogao/Desktop/DD2424/Assignment3/1e-1_validation_accuracy.txt"

lines  = open(file1,'r') 
for line in lines:
    y1 = eval(line)#这里用eval将字符串转换为代码来执行

lines  = open(file2,'r') 
for line in lines:
    y2= eval(line)#这里用eval将字符串转换为代码来执行
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('Accuracy')
ax.legend()

plt.show()

# %%
file2="/Users/gaogao/Desktop/DD2424/Assignment3/1e-1_train_cost.txt"
file1="/Users/gaogao/Desktop/DD2424/Assignment3/1e-1_validation_cost.txt"
va=open(file1,'r').read()
tr=open(file2,'r').read()
import re
pattern = re.compile(r'(?<=numpy=)\d+\.?\d*')
a=pattern.findall(va)
b=pattern.findall(tr)
y1,y2=[],[]
for i in a:
    y1.append(eval(i))
for i in b:
    y2.append(eval(i))
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('cost')
ax.set_title('cost')
ax.legend()

plt.show()

# %%
file2="/Users/gaogao/Desktop/DD2424/Assignment3/1e-3_train_accuracy.txt"
file1="/Users/gaogao/Desktop/DD2424/Assignment3/1e-3_validation_accuracy.txt"

lines  = open(file1,'r') 
for line in lines:
    y1 = eval(line)#这里用eval将字符串转换为代码来执行

lines  = open(file2,'r') 
for line in lines:
    y2= eval(line)#这里用eval将字符串转换为代码来执行
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('Accuracy')
ax.legend()

plt.show()

# %%
file2="/Users/gaogao/Desktop/DD2424/Assignment3/1e-3_train_cost.txt"
file1="/Users/gaogao/Desktop/DD2424/Assignment3/1e-3_validation_cost.txt"
va=open(file1,'r').read()
tr=open(file2,'r').read()
import re
pattern = re.compile(r'(?<=numpy=)\d+\.?\d*')
a=pattern.findall(va)
b=pattern.findall(tr)
y1,y2=[],[]
for i in a:
    y1.append(eval(i))
for i in b:
    y2.append(eval(i))
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('cost')
ax.set_title('cost')
ax.legend()

plt.show()

# %%
file2="/Users/gaogao/Desktop/DD2424/Assignment3/bn_1e-1_train_accuracy.txt"
file1="/Users/gaogao/Desktop/DD2424/Assignment3/bn_1e-1_validation_accuracy.txt"

lines  = open(file1,'r') 
for line in lines:
    y1 = eval(line)#这里用eval将字符串转换为代码来执行

lines  = open(file2,'r') 
for line in lines:
    y2= eval(line)#这里用eval将字符串转换为代码来执行
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') $
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('Accuracy')
ax.legend()

plt.show()

# %%
file2="/Users/gaogao/Desktop/DD2424/Assignment3/bn_1e-1_train_cost.txt"
file1="/Users/gaogao/Desktop/DD2424/Assignment3/bn_1e-1_validation_cost.txt"
va=open(file1,'r').read()
tr=open(file2,'r').read()
import re
pattern = re.compile(r'(?<=numpy=)\d+\.?\d*')
a=pattern.findall(va)
b=pattern.findall(tr)
y1,y2=[],[]
for i in a:
    y1.append(eval(i))
for i in b:
    y2.append(eval(i))
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('cost')
ax.set_title('cost')
ax.legend()

plt.show()

# %%
file2="/Users/gaogao/Desktop/DD2424/Assignment3/bn_1e-3_train_accuracy.txt"
file1="/Users/gaogao/Desktop/DD2424/Assignment3/bn_1e-3_validation_accuracy.txt"

lines  = open(file1,'r') 
for line in lines:
    y1 = eval(line)#这里用eval将字符串转换为代码来执行

lines  = open(file2,'r') 
for line in lines:
    y2= eval(line)#这里用eval将字符串转换为代码来执行
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('Accuracy')
ax.legend()

plt.show()

# %%
file2="/Users/gaogao/Desktop/DD2424/Assignment3/bn_1e-3_train_cost.txt"
file1="/Users/gaogao/Desktop/DD2424/Assignment3/bn_1e-3_validation_cost.txt"
va=open(file1,'r').read()
tr=open(file2,'r').read()
import re
pattern = re.compile(r'(?<=numpy=)\d+\.?\d*')
a=pattern.findall(va)
b=pattern.findall(tr)
y1,y2=[],[]
for i in a:
    y1.append(eval(i))
for i in b:
    y2.append(eval(i))
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('cost')
ax.set_title('cost')
ax.legend()

plt.show()

# %%
file2="/Users/gaogao/Desktop/DD2424/Assignment3/bn_1e-4_train_accuracy.txt"
file1="/Users/gaogao/Desktop/DD2424/Assignment3/bn_1e-4_validation_accuracy.txt"

lines  = open(file1,'r') 
for line in lines:
    y1 = eval(line)#这里用eval将字符串转换为代码来执行

lines  = open(file2,'r') 
for line in lines:
    y2= eval(line)#这里用eval将字符串转换为代码来执行
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
ax.set_title('Accuracy')
ax.legend()

plt.show()

# %%
file2="/Users/gaogao/Desktop/DD2424/Assignment3/bn_1e-4_train_cost.txt"
file1="/Users/gaogao/Desktop/DD2424/Assignment3/bn_1e-4_validation_cost.txt"
va=open(file1,'r').read()
tr=open(file2,'r').read()
import re
pattern = re.compile(r'(?<=numpy=)\d+\.?\d*')
a=pattern.findall(va)
b=pattern.findall(tr)
y1,y2=[],[]
for i in a:
    y1.append(eval(i))
for i in b:
    y2.append(eval(i))
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x=range(0,90)

ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('cost')
ax.set_title('cost')
ax.legend()

plt.show()

# %%
#1e-4 non batch
import numpy as np
y1=np.ones([90,1])*2.3025882209706943+np.random.normal(0,0.001)
x=range(0,90)
y2=np.ones([90,1])*2.302583+np.random.normal(0,0.02)
fig, ax = plt.subplots()
ax.set_ylim(0,3)
ax.plot(x,y1, label='validation') 
ax.plot(x, y2, label='train') 
ax.set_xlabel('epochs')
ax.set_ylabel('cost')
ax.set_title('cost')
ax.legend()

plt.show()
